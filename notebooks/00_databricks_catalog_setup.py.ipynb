# %% [markdown]
# ### Step 1 — Create a Catalog/Schema/Volume for streaming

# %%
# %sql
CREATE CATALOG IF NOT EXISTS streaming_demo;
USE CATALOG streaming_demo;
CREATE SCHEMA IF NOT EXISTS sales;
USE SCHEMA sales;

-- Landing zone for incoming JSON files
CREATE VOLUME IF NOT EXISTS raw_transactions;

-- Checkpoint location for streaming state
CREATE VOLUME IF NOT EXISTS checkpoints;
